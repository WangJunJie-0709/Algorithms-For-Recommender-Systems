# %%
import pandas as pd
import torch.nn as nn
import torch
from torch import optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import torch.nn.functional as F
from torch.autograd import Variable
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
def load_data(path):
    Data = pd.read_csv(path, nrows=50000)
    Data = pd.pivot_table(Data, index='userId', columns='movieId', values='rating')
    return Data
UserItemMatrix = load_data(r'G:\github项目\Recomendation_system\Data\movie\ratings.csv')

# %%
UserItemMatrix.head()
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10      ...  191005  193565  193567  193571  193573  193579  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  193581  193583  193585  193587
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
#
# [5 rows x 6908 columns]

# %%
def divide(Data, k):
    """
    将用户评分矩阵分解成用户向量和物品向量, k为隐特征的个数
    返回所有值初始化的用户和物品隐矩阵
    """
    
    # 这里先用随机化用户和物品向量代替Embedding过程，重点是完成模型的建立，之后进行到第三部分Embedding再补充
    users = Data.index
    items = Data.columns
    features = ['feature' + str(i + 1) for i in range(k)]
    Users = pd.DataFrame(np.random.rand(len(users), k), index=users, columns=features)
    Items = pd.DataFrame(np.random.rand(k, len(items)), index=features, columns=items)
    return Users, Items
Users, Items = divide(UserItemMatrix, 20)

# %%
def get_data(UserItemMatrix, Users, Items):
    """根据用户-物品评分矩阵中确切已知的值，分别得到用户隐向量和物品隐向量，分别构建数据"""
    hold_user_item = [] # 记录对应的用户id和物品id
    users_data = [] 
    items_data = [] # 分别记录下未缺失值的用户和物品隐向量
    score = [] # 记录对应的评分，用作训练的标签
    
    for uid in UserItemMatrix.index:
        for iid in UserItemMatrix.columns:
            p = UserItemMatrix.loc[uid].loc[iid]
            if pd.isnull(p) == False:
                hold_user_item.append([uid, iid])
                users_data.append(Users.loc[uid].values)
                items_data.append(Items.loc[:, iid].values)
                score.append(p)
    
    # 将数据转换为tensor格式，以便于之后训练
    users_data = np.array(users_data)
    items_data = np.array(items_data)
    score = np.array(score)
    users_data = torch.from_numpy(users_data)
    items_data = torch.from_numpy(items_data)
    score = torch.from_numpy(score)
    return hold_user_item, users_data, items_data, score

# %%
def split_data(UserItemMatrix, ratio=0.8):
    
    # 得到用户和物品的隐向量，以及预测的评分
    hold_user_item, users_data, items_data, score = get_data(UserItemMatrix, Users, Items)
    
    # 得到样本数
    sample_number = len(users_data)
    
    # 划分训练数据和验证数据
    Train_users_data = users_data[:int(sample_number*ratio), :]
    Train_items_data = items_data[:int(sample_number*ratio), :]
    Train_target = score[:int(sample_number*ratio)]
    
    Val_users_data = users_data[int(sample_number*ratio):, :]
    Val_items_data = items_data[int(sample_number*ratio):, :]
    Val_target = score[int(sample_number*ratio):]
    
    return Train_users_data, Train_items_data, Train_target, Val_users_data, Val_items_data, Val_target
Train_users_data, Train_items_data, Train_target, Val_users_data, Val_items_data, Val_target = split_data(UserItemMatrix)

# %%
class MyDataset(Dataset):
    # 构建数据集
    def __init__(self, User_Data, Item_Data, Target):
        self.User_Data = User_Data
        self.Item_Data = Item_Data
        self.Target = Target
        
    def __getitem__(self, index):
        sample = {'user': self.User_Data[index], 'item': self.Item_Data[index], 'target': self.Target[index]}
        return sample
        
    def __len__(self):
        return len(self.User_Data)

# %%
Train_Dataset = MyDataset(Train_users_data, Train_items_data, Train_target)
Val_Dataset = MyDataset(Val_users_data, Val_items_data, Val_target)

# %%
class NeuralCF(nn.Module):
    def __init__(self, hidden_units, fea_number):
        super(NeuralCF, self).__init__()
        self.hidden_units = hidden_units
        self.fea_number = fea_number
        
        # MLP部分
        self.L1 = nn.Linear(2 * self.fea_number, hidden_units[0])
        self.relu1 = nn.ReLU()
        self.L2 = nn.Linear(hidden_units[0], hidden_units[1])
        self.relu2 = nn.ReLU()
        self.L3 = nn.Linear(hidden_units[1], hidden_units[2])
        self.relu3 = nn.ReLU()
        self.L4 = nn.Linear(hidden_units[2], hidden_units[3])
        self.relu4 = nn.ReLU()
        self.L5 = nn.Linear(hidden_units[3], hidden_units[4])
        self.relu5 = nn.ReLU()
    
        # NeuralCF层
        self.NeuralCF = nn.Linear(hidden_units[4], 1)
        
    def forward(self, user, item):
        # 进入GMF部分
        x1 = torch.multiply(user, item)
        
        # 进入MLP部分
        x2 = torch.cat((user, item), 1)  # 按列合并
        x2 = self.relu1(self.L1(x2))
        x2 = self.relu2(self.L2(x2))
        x2 = self.relu3(self.L3(x2))
        x2 = self.relu4(self.L4(x2))
        x2 = self.relu5(self.L5(x2))
        
        # 共同进入NeuralCF层
        x3 = x1 + x2
        output = self.NeuralCF(x3)
        
        return output

# %%
# 定义优化器、损失函数、学习率、batchsize
hidden_units = [40, 35, 30, 25, 20]
model = NeuralCF(hidden_units, len(Train_items_data[0]))

loss_fn = nn.MSELoss()

batchsize = 64
Train_Dataloader = DataLoader(Train_Dataset, batch_size=batchsize)
Val_Dataloader = DataLoader(Val_Dataset, batch_size=batchsize)

lr = 0.005
optimizer = optim.SGD(model.parameters(), lr)

# %%
model
# Out:
# NeuralCF(
#   (L1): Linear(in_features=40, out_features=40, bias=True)
#   (relu1): ReLU()
#   (L2): Linear(in_features=40, out_features=35, bias=True)
#   (relu2): ReLU()
#   (L3): Linear(in_features=35, out_features=30, bias=True)
#   (relu3): ReLU()
#   (L4): Linear(in_features=30, out_features=25, bias=True)
#   (relu4): ReLU()
#   (L5): Linear(in_features=25, out_features=20, bias=True)
#   (relu5): ReLU()
#   (NeuralCF): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
def train(model, Train_Loader, Val_loader, loss_fn, optim, epoches=100):
    model.train()
    for epoch in range(epoches):
        print('第{}轮训练开始, 共{}轮'.format(epoch+1, epoches))
        train_loss = 0
        for i, sample in enumerate(Train_Loader):
            user, item = Variable(sample['user'].type(torch.FloatTensor)), Variable(sample['item'].type(torch.FloatTensor))
            target = Variable(sample['target'])
            output = model(user, item)
            loss = loss_fn(output, target.float())
            
            # 优化器优化模型
            optim.zero_grad()
            loss.backward()
            optim.step()
            
            train_loss += loss
        
        model.eval()
        eval_loss = 0
        for i, sample in enumerate(Val_loader):
            user, item = Variable(sample['user'].type(torch.FloatTensor)), Variable(sample['item'].type(torch.FloatTensor))
            target = Variable(sample['target'])
            output = model(user, item)
            loss = loss_fn(output, target.float())
            
            eval_loss += loss
        
        print("第{}轮训练完成, 训练损失为{}, 验证损失为{}".format(epoch+1, train_loss, eval_loss))
    return model

# %%
trained_model = train(model, Train_Dataloader, Val_Dataloader, loss_fn, optimizer)
# Out:
# 第1轮训练开始, 共100轮
# C:\Users\ASUS\anaconda3\lib\site-packages\torch\nn\modules\loss.py:528: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\ASUS\anaconda3\lib\site-packages\torch\nn\modules\loss.py:528: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# 第1轮训练完成, 训练损失为871.9234008789062, 验证损失为226.93972778320312
# 第2轮训练开始, 共100轮
# 第2轮训练完成, 训练损失为672.9725341796875, 验证损失为222.42926025390625
# 第3轮训练开始, 共100轮
# 第3轮训练完成, 训练损失为664.5673217773438, 验证损失为219.36814880371094
# 第4轮训练开始, 共100轮
# 第4轮训练完成, 训练损失为658.5121459960938, 验证损失为217.1940460205078
# 第5轮训练开始, 共100轮
# 第5轮训练完成, 训练损失为653.91943359375, 验证损失为215.6185302734375
# 第6轮训练开始, 共100轮
# 第6轮训练完成, 训练损失为650.2606201171875, 验证损失为214.46090698242188
# 第7轮训练开始, 共100轮
# 第7轮训练完成, 训练损失为647.2781982421875, 验证损失为213.5484161376953
# 第8轮训练开始, 共100轮
# 第8轮训练完成, 训练损失为644.833984375, 验证损失为212.78189086914062
# 第9轮训练开始, 共100轮
# 第9轮训练完成, 训练损失为642.7901000976562, 验证损失为212.13436889648438
# 第10轮训练开始, 共100轮
# 第10轮训练完成, 训练损失为641.037353515625, 验证损失为211.57933044433594
# 第11轮训练开始, 共100轮
# 第11轮训练完成, 训练损失为639.50830078125, 验证损失为211.08323669433594
# 第12轮训练开始, 共100轮
# 第12轮训练完成, 训练损失为638.1583862304688, 验证损失为210.61866760253906
# 第13轮训练开始, 共100轮
# 第13轮训练完成, 训练损失为636.964599609375, 验证损失为210.17982482910156
# 第14轮训练开始, 共100轮
# 第14轮训练完成, 训练损失为635.899658203125, 验证损失为209.75161743164062
# 第15轮训练开始, 共100轮
# 第15轮训练完成, 训练损失为634.9490356445312, 验证损失为209.3393096923828
# 第16轮训练开始, 共100轮
# 第16轮训练完成, 训练损失为634.1036987304688, 验证损失为208.93695068359375
# 第17轮训练开始, 共100轮
# 第17轮训练完成, 训练损失为633.3470458984375, 验证损失为208.55494689941406
# 第18轮训练开始, 共100轮
# 第18轮训练完成, 训练损失为632.6763305664062, 验证损失为208.17776489257812
# 第19轮训练开始, 共100轮
# 第19轮训练完成, 训练损失为632.0966186523438, 验证损失为207.80345153808594
# 第20轮训练开始, 共100轮
# 第20轮训练完成, 训练损失为631.6011352539062, 验证损失为207.43136596679688
# 第21轮训练开始, 共100轮
# 第21轮训练完成, 训练损失为631.1644287109375, 验证损失为207.072265625
# 第22轮训练开始, 共100轮
# 第22轮训练完成, 训练损失为630.7996826171875, 验证损失为206.71148681640625
# 第23轮训练开始, 共100轮
# 第23轮训练完成, 训练损失为630.5071411132812, 验证损失为206.33050537109375
# 第24轮训练开始, 共100轮
# 第24轮训练完成, 训练损失为630.2901000976562, 验证损失为205.9678497314453
# 第25轮训练开始, 共100轮
# 第25轮训练完成, 训练损失为630.0892333984375, 验证损失为205.62124633789062
# 第26轮训练开始, 共100轮
# 第26轮训练完成, 训练损失为629.9464111328125, 验证损失为205.27230834960938
# 第27轮训练开始, 共100轮
# 第27轮训练完成, 训练损失为629.83154296875, 验证损失为204.92587280273438
# 第28轮训练开始, 共100轮
# 第28轮训练完成, 训练损失为629.7361450195312, 验证损失为204.6100311279297
# 第29轮训练开始, 共100轮
# 第29轮训练完成, 训练损失为629.655029296875, 验证损失为204.3184051513672
# 第30轮训练开始, 共100轮
# 第30轮训练完成, 训练损失为629.6019897460938, 验证损失为204.02667236328125
# 第31轮训练开始, 共100轮
# 第31轮训练完成, 训练损失为629.550537109375, 验证损失为203.74461364746094
# 第32轮训练开始, 共100轮
# 第32轮训练完成, 训练损失为629.5118408203125, 验证损失为203.4925079345703
# 第33轮训练开始, 共100轮
# 第33轮训练完成, 训练损失为629.4483642578125, 验证损失为203.27145385742188
# 第34轮训练开始, 共100轮
# 第34轮训练完成, 训练损失为629.3941040039062, 验证损失为203.05259704589844
# 第35轮训练开始, 共100轮
# 第35轮训练完成, 训练损失为629.3291625976562, 验证损失为202.84445190429688
# 第36轮训练开始, 共100轮
# 第36轮训练完成, 训练损失为629.2754516601562, 验证损失为202.63815307617188
# 第37轮训练开始, 共100轮
# 第37轮训练完成, 训练损失为629.1941528320312, 验证损失为202.47064208984375
# 第38轮训练开始, 共100轮
# 第38轮训练完成, 训练损失为629.1021728515625, 验证损失为202.31373596191406
# 第39轮训练开始, 共100轮
# 第39轮训练完成, 训练损失为628.9972534179688, 验证损失为202.16412353515625
# 第40轮训练开始, 共100轮
# 第40轮训练完成, 训练损失为628.8851318359375, 验证损失为202.0290069580078
# 第41轮训练开始, 共100轮
# 第41轮训练完成, 训练损失为628.76220703125, 验证损失为201.8927459716797
# 第42轮训练开始, 共100轮
# 第42轮训练完成, 训练损失为628.637451171875, 验证损失为201.78993225097656
# 第43轮训练开始, 共100轮
# 第43轮训练完成, 训练损失为628.4883422851562, 验证损失为201.68968200683594
# 第44轮训练开始, 共100轮
# 第44轮训练完成, 训练损失为628.3057861328125, 验证损失为201.6006622314453
# 第45轮训练开始, 共100轮
# 第45轮训练完成, 训练损失为628.093017578125, 验证损失为201.53848266601562
# 第46轮训练开始, 共100轮
# 第46轮训练完成, 训练损失为627.8533935546875, 验证损失为201.48692321777344
# 第47轮训练开始, 共100轮
# 第47轮训练完成, 训练损失为627.59130859375, 验证损失为201.45101928710938
# 第48轮训练开始, 共100轮
# 第48轮训练完成, 训练损失为627.2998657226562, 验证损失为201.41635131835938
# 第49轮训练开始, 共100轮
# 第49轮训练完成, 训练损失为626.9628295898438, 验证损失为201.41163635253906
# 第50轮训练开始, 共100轮
# 第50轮训练完成, 训练损失为626.58642578125, 验证损失为201.4244384765625
# 第51轮训练开始, 共100轮
# 第51轮训练完成, 训练损失为626.1613159179688, 验证损失为201.45159912109375
# 第52轮训练开始, 共100轮
# 第52轮训练完成, 训练损失为625.6937255859375, 验证损失为201.5072784423828
# 第53轮训练开始, 共100轮
# 第53轮训练完成, 训练损失为625.1774291992188, 验证损失为201.56576538085938
# 第54轮训练开始, 共100轮
# 第54轮训练完成, 训练损失为624.5943603515625, 验证损失为201.64096069335938
# 第55轮训练开始, 共100轮
# 第55轮训练完成, 训练损失为623.9595336914062, 验证损失为201.74180603027344
# 第56轮训练开始, 共100轮
# 第56轮训练完成, 训练损失为623.2610473632812, 验证损失为201.88449096679688
# 第57轮训练开始, 共100轮
# 第57轮训练完成, 训练损失为622.5110473632812, 验证损失为202.0612030029297
# 第58轮训练开始, 共100轮
# 第58轮训练完成, 训练损失为621.7220458984375, 验证损失为202.2587890625
# 第59轮训练开始, 共100轮
# 第59轮训练完成, 训练损失为620.8804321289062, 验证损失为202.4922332763672
# 第60轮训练开始, 共100轮
# 第60轮训练完成, 训练损失为619.9784545898438, 验证损失为202.74649047851562
# 第61轮训练开始, 共100轮
# 第61轮训练完成, 训练损失为619.049560546875, 验证损失为203.05810546875
# 第62轮训练开始, 共100轮
# 第62轮训练完成, 训练损失为618.0932006835938, 验证损失为203.38101196289062
# 第63轮训练开始, 共100轮
# 第63轮训练完成, 训练损失为617.1018676757812, 验证损失为203.73199462890625
# 第64轮训练开始, 共100轮
# 第64轮训练完成, 训练损失为616.0706787109375, 验证损失为204.1514434814453
# 第65轮训练开始, 共100轮
# 第65轮训练完成, 训练损失为614.9951171875, 验证损失为204.56146240234375
# 第66轮训练开始, 共100轮
# 第66轮训练完成, 训练损失为613.9822387695312, 验证损失为205.03262329101562
# 第67轮训练开始, 共100轮
# 第67轮训练完成, 训练损失为612.9497680664062, 验证损失为205.50823974609375
# 第68轮训练开始, 共100轮
# 第68轮训练完成, 训练损失为611.9172973632812, 验证损失为205.98841857910156
# 第69轮训练开始, 共100轮
# 第69轮训练完成, 训练损失为610.8513793945312, 验证损失为206.45631408691406
# 第70轮训练开始, 共100轮
# 第70轮训练完成, 训练损失为609.8690795898438, 验证损失为206.91444396972656
# 第71轮训练开始, 共100轮
# 第71轮训练完成, 训练损失为608.8709106445312, 验证损失为207.34841918945312
# 第72轮训练开始, 共100轮
# 第72轮训练完成, 训练损失为607.8967895507812, 验证损失为207.77500915527344
# 第73轮训练开始, 共100轮
# 第73轮训练完成, 训练损失为606.9457397460938, 验证损失为208.16696166992188
# 第74轮训练开始, 共100轮
# 第74轮训练完成, 训练损失为606.0462646484375, 验证损失为208.59288024902344
# 第75轮训练开始, 共100轮
# 第75轮训练完成, 训练损失为605.1465454101562, 验证损失为209.027099609375
# 第76轮训练开始, 共100轮
# 第76轮训练完成, 训练损失为604.2423706054688, 验证损失为209.46966552734375
# 第77轮训练开始, 共100轮
# 第77轮训练完成, 训练损失为603.360595703125, 验证损失为209.86392211914062
# 第78轮训练开始, 共100轮
# 第78轮训练完成, 训练损失为602.4977416992188, 验证损失为210.32435607910156
# 第79轮训练开始, 共100轮
# 第79轮训练完成, 训练损失为601.6284790039062, 验证损失为210.7969512939453
# 第80轮训练开始, 共100轮
# 第80轮训练完成, 训练损失为600.8331909179688, 验证损失为211.27110290527344
# 第81轮训练开始, 共100轮
# 第81轮训练完成, 训练损失为600.0700073242188, 验证损失为211.7216033935547
# 第82轮训练开始, 共100轮
# 第82轮训练完成, 训练损失为599.4041137695312, 验证损失为212.18113708496094
# 第83轮训练开始, 共100轮
# 第83轮训练完成, 训练损失为598.7667846679688, 验证损失为212.59620666503906
# 第84轮训练开始, 共100轮
# 第84轮训练完成, 训练损失为598.2041015625, 验证损失为213.00827026367188
# 第85轮训练开始, 共100轮
# 第85轮训练完成, 训练损失为597.6345825195312, 验证损失为213.46395874023438
# 第86轮训练开始, 共100轮
# 第86轮训练完成, 训练损失为597.1015014648438, 验证损失为213.84129333496094
# 第87轮训练开始, 共100轮
# 第87轮训练完成, 训练损失为596.5648803710938, 验证损失为214.29278564453125
# 第88轮训练开始, 共100轮
# 第88轮训练完成, 训练损失为596.0476684570312, 验证损失为214.7136688232422
# 第89轮训练开始, 共100轮
# 第89轮训练完成, 训练损失为595.5484008789062, 验证损失为215.1273193359375
# 第90轮训练开始, 共100轮
# 第90轮训练完成, 训练损失为595.0769653320312, 验证损失为215.50950622558594
# 第91轮训练开始, 共100轮
# 第91轮训练完成, 训练损失为594.6668090820312, 验证损失为215.97640991210938
# 第92轮训练开始, 共100轮
# 第92轮训练完成, 训练损失为594.2504272460938, 验证损失为216.37535095214844
# 第93轮训练开始, 共100轮
# 第93轮训练完成, 训练损失为593.8596801757812, 验证损失为216.8343963623047
# 第94轮训练开始, 共100轮
# 第94轮训练完成, 训练损失为593.4756469726562, 验证损失为217.34695434570312
# 第95轮训练开始, 共100轮
# 第95轮训练完成, 训练损失为593.1358032226562, 验证损失为217.8871612548828
# 第96轮训练开始, 共100轮
# 第96轮训练完成, 训练损失为592.776611328125, 验证损失为218.40382385253906
# 第97轮训练开始, 共100轮
# 第97轮训练完成, 训练损失为592.456298828125, 验证损失为218.89166259765625
# 第98轮训练开始, 共100轮
# 第98轮训练完成, 训练损失为592.1407470703125, 验证损失为219.45162963867188
# 第99轮训练开始, 共100轮
# 第99轮训练完成, 训练损失为591.8442993164062, 验证损失为219.9167938232422
# 第100轮训练开始, 共100轮
# 第100轮训练完成, 训练损失为591.5590209960938, 验证损失为220.38510131835938
