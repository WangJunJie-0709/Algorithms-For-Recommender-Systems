# %%
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torch
from torch import nn, optim
from collections import OrderedDict
import torch.nn.functional as F
from torch.autograd import Variable
from sklearn import preprocessing

# %%
"""处理数据，构建数据集部分"""
# Out:
# '处理数据，构建数据集部分'

# %%
def load_data(path):
    Data = pd.read_csv(path, nrows=10000)
    return Data
Data = load_data('G:\github项目\Recomendation_system\Data\criteo_sample\criteo_sampled_data.csv')

# %%
Data.head()
# Out:
#    label   I1   I2    I3    I4      I5    I6    I7   I8     I9  ...       C17  \
# 0      0  1.0    1   5.0   0.0  1382.0   4.0  15.0  2.0  181.0  ...  e5ba7672
# 1      0  2.0    0  44.0   1.0   102.0   8.0   2.0  2.0    4.0  ...  07c540c4
# 2      0  2.0    0   1.0  14.0   767.0  89.0   4.0  2.0  245.0  ...  8efede7f
# 3      0  NaN  893   NaN   NaN  4392.0   NaN   0.0  0.0    0.0  ...  1e88c74f
# 4      0  3.0   -1   NaN   0.0     2.0   0.0   3.0  0.0    0.0  ...  1e88c74f
#
#         C18       C19       C20       C21       C22       C23       C24  \
# 0  f54016b9  21ddcdc9  b1252a9d  07b5194c       NaN  3a171ecb  c5c50484
# 1  b04e4670  21ddcdc9  5840adea  60f6221e       NaN  3a171ecb  43f13e8b
# 2  3412118d       NaN       NaN  e587c466  ad3062eb  3a171ecb  3b183c5c
# 3  74ef3502       NaN       NaN  6b3a5ca6       NaN  3a171ecb  9117a34a
# 4  26b3c7a7       NaN       NaN  21c9516a       NaN  32c7478e  b34f3128
#
#         C25       C26
# 0  e8b83407  9727dd16
# 1  e8b83407  731c3655
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 40 columns]

# %%
def Nan_process(Data):
    """补充数据中的缺失值，这里重点是构建模型，大家可自行优化数据缺失值的处理方法"""
    columns = Data.columns
    for column in columns:
        Data[column] = Data[column].fillna(method='bfill') 
        Data[column] = Data[column].fillna(method='pad') # 分别是用缺失值后面的值和前面的值进行填充
    return Data
Data = Nan_process(Data)

# %%
dense_fea, sparse_fea = Data.columns[1:14], Data.columns[14:]

# %%
len(sparse_fea)
# Out:
# 26

# %%
def process_Data(Data, ratio=0.8):
    """划分训练数据集和验证数据集"""
    Le = preprocessing.LabelEncoder()
    n = len(Data.index) # 数据的长度
    Train_Data = Data[:int(n*ratio)]
    Val_Data = Data[int(n*ratio):]
    Train_Count_Data = Train_Data.iloc[:, :14]
    Val_Count_Data = Val_Data.iloc[:, :14]
    Train_Type_Data = Train_Data.iloc[:, 14:]
    Val_Type_Data = Val_Data.iloc[:, 14:]
    columns = Train_Type_Data.columns
    for column in columns:
        # 将类别型离散特征编码, 使用LabelEncoder编码
        Train_Type_Data[column] = Le.fit_transform(Train_Type_Data[column])
        Val_Type_Data[column] = Le.fit_transform(Val_Type_Data[column])
    Train_Type_Data = torch.from_numpy(Train_Type_Data.values.astype(float))
    Val_Type_Data = torch.from_numpy(Val_Type_Data.values.astype(float))
    Train_Count_Data = torch.from_numpy(Train_Count_Data.values.astype(float))
    Val_Count_Data = torch.from_numpy(Val_Count_Data.values.astype(float))
    return Train_Count_Data, Val_Count_Data, Train_Type_Data, Val_Type_Data
Train_Count_Data, Val_Count_Data, Train_Type_Data, Val_Type_Data = process_Data(Data)

# %%
Train_Type_Data[:,25]
# Out:
# tensor([ 972.,  734., 1001.,  ...,  393.,  128., 1181.], dtype=torch.float64)

# %%
class MyDataset(Dataset):
    # 构建数据集
    def __init__(self, Count_Data, Type_Data):
        self.label = Count_Data[:, 0]  # 将标签分离出来
        self.countx = Count_Data[:, 1:]
        self.typex = Type_Data[:, ]
    
    def __getitem__(self, index):
        sample = {'typex':self.typex[index], 'label':self.label[index], 'countx':self.countx[index]}
        return sample
        
    def __len__(self):
        return len(self.countx[:, 0])

# %%
Train_Dataset = MyDataset(Train_Count_Data, Train_Type_Data)
Val_Dataset = MyDataset(Val_Count_Data, Val_Type_Data)

# %%
class Residual_block(nn.Module):
    """定义残差块"""
    def __init__(self, hidden_units, dim_stack):
        super(Residual_block, self).__init__()
        self.L1 = nn.Linear(dim_stack, hidden_units)
        self.L2 = nn.Linear(hidden_units, dim_stack)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        out1 = self.L1(x)
        out1 = self.relu(out1)
        out1 = self.L2(out1)
        out = self.relu(out1 + x)  # 残差连接
        return out

# %%
class DeepCrossing(nn.Module):
    def __init__(self, dense_fea, sparse_fea, hidden_units, dropout=0, embed_dim=20, output_dim=1):
        super(DeepCrossing, self).__init__()
        self.dense_fea = dense_fea
        self.sparse_fea = sparse_fea
        self.hidden_units = hidden_units
        
        # Embedding层
        self.embed_layers = nn.ModuleDict({
            'embed'+str(i):nn.Embedding(num_embeddings=10000, embedding_dim=embed_dim)
            for i in range(len(self.sparse_fea))
        })
        embed_dim_sum = len(self.sparse_fea) * embed_dim
        dim_stack = len(self.dense_fea) + embed_dim_sum
        
        # 残差层
        self.res_layers = nn.ModuleList([
            Residual_block(unit, dim_stack) for unit in self.hidden_units
        ])
        
        # dropout层
        self.drop = nn.Dropout(dropout)
        
        # 线性层
        self.L = nn.Linear(dim_stack, output_dim)
        
    def forward(self, typex, countx):
        typex = typex.long()
        sparse_embeds = [self.embed_layers['embed'+str(i)](typex[:, i]) for i in range(typex.shape[1])]
        sparse_embed = torch.cat(sparse_embeds, axis=-1)
        stack = torch.cat([sparse_embed, countx], axis=-1)
        r = stack
        for res in self.res_layers:
            r = res(r)
            
        r = self.drop(r)
        outputs = F.sigmoid(self.L(r))
        outputs = outputs.squeeze(-1)
        return outputs

# %%
# 定义优化器、损失函数、学习率、batchsize
hidden_units = [256, 128, 64, 32]
model = DeepCrossing(dense_fea, sparse_fea, hidden_units)

loss_fn = nn.BCELoss()

batchsize = 16
Train_Dataloader = DataLoader(Train_Dataset, batch_size=batchsize)
Val_Dataloader = DataLoader(Val_Dataset, batch_size=batchsize)

lr = 0.001
optimizer = optim.SGD(model.parameters(), lr)

# %%
def train(model, Train_Loader, Val_loader, loss_fn, optim, epoches=100):
    model.train()
    for epoch in range(epoches):
        print('第{}轮训练开始，共{}轮'.format(epoch+1, epoches))
        train_loss = 0
        for i, sample in enumerate(Train_Loader):
            typex, countx = Variable(sample['typex'].type(torch.FloatTensor)), Variable(sample['countx'].type(torch.FloatTensor))
            label = Variable(sample['label'])
            output = model(typex, countx)
            loss = loss_fn(output, label.float())
            
            # 优化器优化模型
            optim.zero_grad()
            loss.backward()
            optim.step()
            
            train_loss += loss.item()
        
        model.eval()
        eval_loss = 0
        for i, sample in enumerate(Val_loader):
            val_typex, val_countx = Variable(sample['typex'].type(torch.FloatTensor)), Variable(sample['countx'].type(torch.FloatTensor))
            val_label = Variable(sample['label'])
            val_output = model(val_typex, val_countx)
            val_loss = loss_fn(val_output, val_label.float())
            
            eval_loss += val_loss.item()
        
        print('第{}轮训练完成，训练误差为{}，验证误差为{}'.format(epoch+1, train_loss, eval_loss))
    return model

# %%
model = train(model, Train_Dataloader, Val_Dataloader, loss_fn, optimizer)
# Out:
# 第1轮训练开始，共100轮
# 第1轮训练完成，训练误差为8368.354330598995，验证误差为2144.3956311643124
# 第2轮训练开始，共100轮
# 第2轮训练完成，训练误差为8666.79010393328，验证误差为2178.4804430492804
# 第3轮训练开始，共100轮
# 第3轮训练完成，训练误差为7972.506401168183，验证误差为2087.302914537951
# 第4轮训练开始，共100轮
# 第4轮训练完成，训练误差为8359.864625616861，验证误差为2169.6895073736086
# 第5轮训练开始，共100轮
# 第5轮训练完成，训练误差为8356.06542723245，验证误差为2202.2295188605785
# 第6轮训练开始，共100轮
# 第6轮训练完成，训练误差为8157.926548386501，验证误差为2206.2750504803844
# 第7轮训练开始，共100轮
# 第7轮训练完成，训练误差为8034.911266884679，验证误差为2058.862920779735
# 第8轮训练开始，共100轮
# 第8轮训练完成，训练误差为7764.120634795525，验证误差为1679.327098201029
# 第9轮训练开始，共100轮
# 第9轮训练完成，训练误差为11411.643085372634，验证误差为1826.327412892948
# 第10轮训练开始，共100轮
# 第10轮训练完成，训练误差为9004.33558353252，验证误差为1407.100704550743
# 第11轮训练开始，共100轮
# 第11轮训练完成，训练误差为8379.00909963506，验证误差为2071.035608457518
# 第12轮训练开始，共100轮
# 第12轮训练完成，训练误差为7699.935258271336，验证误差为2077.634226680064
# 第13轮训练开始，共100轮
# 第13轮训练完成，训练误差为7556.903384791941，验证误差为2038.0596796125174
# 第14轮训练开始，共100轮
# 第14轮训练完成，训练误差为7721.319726506516，验证误差为1191.537139520049
# 第15轮训练开始，共100轮
# 第15轮训练完成，训练误差为3293.2416157964617，验证误差为601.916201800108
# 第16轮训练开始，共100轮
# 第16轮训练完成，训练误差为3580.149059931377，验证误差为7514.209365844727
# 第17轮训练开始，共100轮
# 第17轮训练完成，训练误差为3151.7412114124745，验证误差为155.40519189834595
# 第18轮训练开始，共100轮
# 第18轮训练完成，训练误差为889.8936581909657，验证误差为128.6852733194828
# 第19轮训练开始，共100轮
# 第19轮训练完成，训练误差为464.34202921390533，验证误差为132.2852129638195
# 第20轮训练开始，共100轮
# 第20轮训练完成，训练误差为407.6366654038429，验证误差为89.16727735102177
# 第21轮训练开始，共100轮
# 第21轮训练完成，训练误差为370.6974339336157，验证误差为127.42414343357086
# 第22轮训练开始，共100轮
# 第22轮训练完成，训练误差为357.5184585303068，验证误差为117.40336403250694
# 第23轮训练开始，共100轮
# 第23轮训练完成，训练误差为371.89831380546093，验证误差为107.39319905638695
# 第24轮训练开始，共100轮
# 第24轮训练完成，训练误差为377.5179770588875，验证误差为107.37283253669739
# 第25轮训练开始，共100轮
# 第25轮训练完成，训练误差为350.59296077489853，验证误差为106.71799629926682
# 第26轮训练开始，共100轮
# 第26轮训练完成，训练误差为354.2165225893259，验证误差为101.69771294295788
# 第27轮训练开始，共100轮
# 第27轮训练完成，训练误差为366.58483853936195，验证误差为93.23918402194977
# 第28轮训练开始，共100轮
# 第28轮训练完成，训练误差为334.1363921314478，验证误差为91.3340707719326
# 第29轮训练开始，共100轮
# 第29轮训练完成，训练误差为324.1333029717207，验证误差为89.54752799868584
# 第30轮训练开始，共100轮
# 第30轮训练完成，训练误差为319.8570137321949，验证误差为82.16580240428448
# 第31轮训练开始，共100轮
# 第31轮训练完成，训练误差为326.2215927094221，验证误差为73.5462266355753
# 第32轮训练开始，共100轮
# 第32轮训练完成，训练误差为317.39537055790424，验证误差为88.7548093944788
# 第33轮训练开始，共100轮
# 第33轮训练完成，训练误差为304.54493372142315，验证误差为87.612205773592
# 第34轮训练开始，共100轮
# 第34轮训练完成，训练误差为310.65217255055904，验证误差为87.44634935259819
# 第35轮训练开始，共100轮
# 第35轮训练完成，训练误差为300.34058275818825，验证误差为81.37711203098297
# 第36轮训练开始，共100轮
# 第36轮训练完成，训练误差为283.27027897536755，验证误差为81.28176009654999
# 第37轮训练开始，共100轮
# 第37轮训练完成，训练误差为279.9943769425154，验证误差为81.16682381927967
# 第38轮训练开始，共100轮
# 第38轮训练完成，训练误差为298.4792267382145，验证误差为75.73698446154594
# 第39轮训练开始，共100轮
# 第39轮训练完成，训练误差为296.7550039887428，验证误差为75.59146000444889
# 第40轮训练开始，共100轮
# 第40轮训练完成，训练误差为282.3024347424507，验证误差为75.23638640344143
# 第41轮训练开始，共100轮
# 第41轮训练完成，训练误差为275.8535995930433，验证误差为75.00997796654701
# 第42轮训练开始，共100轮
# 第42轮训练完成，训练误差为295.7843699157238，验证误差为74.76355941593647
# 第43轮训练开始，共100轮
# 第43轮训练完成，训练误差为282.71963611245155，验证误差为74.67157410085201
# 第44轮训练开始，共100轮
# 第44轮训练完成，训练误差为287.3285080343485，验证误差为74.84571976959705
# 第45轮训练开始，共100轮
# 第45轮训练完成，训练误差为488.9006070494652，验证误差为93.7624282836914
# 第46轮训练开始，共100轮
# 第46轮训练完成，训练误差为427.855640694499，验证误差为74.67110298573971
# 第47轮训练开始，共100轮
# 第47轮训练完成，训练误差为386.03473491966724，验证误差为72.9598046541214
# 第48轮训练开始，共100轮
# 第48轮训练完成，训练误差为336.50243043899536，验证误差为73.10003046691418
# 第49轮训练开始，共100轮
# 第49轮训练完成，训练误差为299.69385977089405，验证误差为68.90476439893246
# 第50轮训练开始，共100轮
# 第50轮训练完成，训练误差为304.5489452779293，验证误差为67.85898011922836
# 第51轮训练开始，共100轮
# 第51轮训练完成，训练误差为302.6249189674854，验证误差为67.71648624539375
# 第52轮训练开始，共100轮
# 第52轮训练完成，训练误差为348.6088084578514，验证误差为67.52389439940453
# 第53轮训练开始，共100轮
# 第53轮训练完成，训练误差为288.4089778959751，验证误差为66.68623937666416
# 第54轮训练开始，共100轮
# 第54轮训练完成，训练误差为544.1256286352873，验证误差为68.54205361008644
# 第55轮训练开始，共100轮
# 第55轮训练完成，训练误差为307.0797870308161，验证误差为66.39633449912071
# 第56轮训练开始，共100轮
# 第56轮训练完成，训练误差为290.41709838807583，验证误差为71.52030146121979
# 第57轮训练开始，共100轮
# 第57轮训练完成，训练误差为253.1751219779253，验证误差为67.69661279022694
# 第58轮训练开始，共100轮
# 第58轮训练完成，训练误差为262.08062437176704，验证误差为67.32306227087975
# 第59轮训练开始，共100轮
# 第59轮训练完成，训练误差为258.02576883137226，验证误差为67.08961106836796
# 第60轮训练开始，共100轮
# 第60轮训练完成，训练误差为252.43284766376019，验证误差为66.27888789772987
# 第61轮训练开始，共100轮
# 第61轮训练完成，训练误差为254.64474979043007，验证误差为66.87147019803524
# 第62轮训练开始，共100轮
# 第62轮训练完成，训练误差为273.20984818041325，验证误差为67.43639208376408
# 第63轮训练开始，共100轮
# 第63轮训练完成，训练误差为256.82104955613613，验证误差为66.97532224655151
# 第64轮训练开始，共100轮
# 第64轮训练完成，训练误差为252.53279627859592，验证误差为66.82647766172886
# 第65轮训练开始，共100轮
# 第65轮训练完成，训练误差为252.45367394387722，验证误差为66.71062932908535
# 第66轮训练开始，共100轮
# 第66轮训练完成，训练误差为838.5591717809439，验证误差为67.38034084439278
# 第67轮训练开始，共100轮
# 第67轮训练完成，训练误差为255.1208933442831，验证误差为66.64718481898308
# 第68轮训练开始，共100轮
# 第68轮训练完成，训练误差为260.30816860497，验证误差为68.80863007903099
# 第69轮训练开始，共100轮
# 第69轮训练完成，训练误差为287.1192118525505，验证误差为67.13475178182125
# 第70轮训练开始，共100轮
# 第70轮训练完成，训练误差为279.9178347736597，验证误差为66.96490049362183
# 第71轮训练开始，共100轮
# 第71轮训练完成，训练误差为272.34899266064167，验证误差为66.81056198477745
# 第72轮训练开始，共100轮
# 第72轮训练完成，训练误差为251.83745166659355，验证误差为67.11655108630657
# 第73轮训练开始，共100轮
# 第73轮训练完成，训练误差为284.6325935572386，验证误差为67.26478725671768
# 第74轮训练开始，共100轮
# 第74轮训练完成，训练误差为251.07071281969547，验证误差为67.0016998052597
# 第75轮训练开始，共100轮
# 第75轮训练完成，训练误差为277.51483891904354，验证误差为66.71948216855526
# 第76轮训练开始，共100轮
# 第76轮训练完成，训练误差为258.3508178591728，验证误差为67.18907238543034
# 第77轮训练开始，共100轮
# 第77轮训练完成，训练误差为250.94490841031075，验证误差为67.0843128412962
# 第78轮训练开始，共100轮
# 第78轮训练完成，训练误差为866.4444291815162，验证误差为67.04660674929619
# 第79轮训练开始，共100轮
# 第79轮训练完成，训练误差为318.2792173400521，验证误差为67.34869453310966
# 第80轮训练开始，共100轮
# 第80轮训练完成，训练误差为252.57521092891693，验证误差为66.83830296993256
# 第81轮训练开始，共100轮
# 第81轮训练完成，训练误差为250.0958340317011，验证误差为66.99531570076942
# 第82轮训练开始，共100轮
# 第82轮训练完成，训练误差为250.80141489207745，验证误差为67.10214088857174
# 第83轮训练开始，共100轮
# 第83轮训练完成，训练误差为251.87091606855392，验证误差为67.14245295524597
# 第84轮训练开始，共100轮
# 第84轮训练完成，训练误差为419.5120025873184，验证误差为68.2903002500534
# 第85轮训练开始，共100轮
# 第85轮训练完成，训练误差为252.6840307712555，验证误差为67.42386826872826
# 第86轮训练开始，共100轮
# 第86轮训练完成，训练误差为251.14801563322544，验证误差为66.97036418318748
# 第87轮训练开始，共100轮
# 第87轮训练完成，训练误差为258.57837477326393，验证误差为66.7063459455967
# 第88轮训练开始，共100轮
# 第88轮训练完成，训练误差为258.677568256855，验证误差为66.61546137928963
# 第89轮训练开始，共100轮
# 第89轮训练完成，训练误差为249.59721405804157，验证误差为66.56936247646809
# 第90轮训练开始，共100轮
# 第90轮训练完成，训练误差为249.9126181602478，验证误差为66.48684829473495
# 第91轮训练开始，共100轮
# 第91轮训练完成，训练误差为270.5592846572399，验证误差为66.97755134105682
# 第92轮训练开始，共100轮
# 第92轮训练完成，训练误差为256.5687082707882，验证误差为67.08621023595333
# 第93轮训练开始，共100轮
# 第93轮训练完成，训练误差为261.41865861415863，验证误差为66.79197350144386
# 第94轮训练开始，共100轮
# 第94轮训练完成，训练误差为248.34612207114697，验证误差为66.64055947959423
# 第95轮训练开始，共100轮
# 第95轮训练完成，训练误差为248.6055458188057，验证误差为66.54599086940289
# 第96轮训练开始，共100轮
# 第96轮训练完成，训练误差为248.38585175573826，验证误差为66.50232946872711
# 第97轮训练开始，共100轮
# 第97轮训练完成，训练误差为254.6223609149456，验证误差为66.55327719449997
# 第98轮训练开始，共100轮
# 第98轮训练完成，训练误差为248.12164340913296，验证误差为66.91300837695599
# 第99轮训练开始，共100轮
# 第99轮训练完成，训练误差为283.5846497416496，验证误差为66.80926689505577
# 第100轮训练开始，共100轮
# 第100轮训练完成，训练误差为284.3341396898031，验证误差为66.64857620000839
